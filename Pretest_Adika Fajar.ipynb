# %%
import pandas as pd
import statistics as st

# %%
churned = pd.read_csv(r"C:\Users\adikapra\Jupyter\churn.csv", encoding='latin1')
churned.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
churned.shape
# Out:
# (5000, 21)

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import seaborn as sns

# %%
churned.groupby(["state", "class"]).size().unstack().plot(kind='line', stacked=True, figsize=(40,15))

# %%
#churn by area code
churned.groupby(["area_code", "class"]).size().unstack().plot(kind='bar', stacked=True, figsize=(5,5))

# %%
churned.groupby(["international_plan", "class"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5))

# %%
churned.groupby(["voice_mail_plan", "class"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5))

# %%
churned.groupby(["number_customer_service_calls", "class"]).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5))
